# %%
import pandas as pd

# %%
# !pwd
# Out:
# /home/work/ebnerd-benchmark/examples/00_quick_start

# %%
# !ls /home/data/dataset/origin/ebnerd_large/validation
# Out:
# behaviors.parquet  history.parquet

# %%
tmp = pd.read_parquet("/home/data/dataset/origin/ebnerd_large/validation/behaviors.parquet")

# %%
tmp
# Out:
#           impression_id  article_id     impression_time  read_time  \
# 0                 96429         NaN 2023-05-28 04:31:49       19.0
# 1                 96434         NaN 2023-05-28 04:53:56       13.0
# 2                 96436         NaN 2023-05-28 04:58:04       28.0
# 3                 96443         NaN 2023-05-28 04:58:42       24.0
# 4                 96462         NaN 2023-05-28 04:15:23       10.0
# ...                 ...         ...                 ...        ...
# 12566380      579553939         NaN 2023-05-27 19:36:06       16.0
# 12566381      579553955   9782656.0 2023-05-27 19:18:09       22.0
# 12566382      579553959   9782656.0 2023-05-27 19:19:44        9.0
# 12566383      579553969   9782656.0 2023-05-27 19:17:18       11.0
# 12566384      579553971   9782656.0 2023-05-27 19:21:29       16.0
#
#           scroll_percentage  device_type  \
# 0                       NaN            2
# 1                       NaN            2
# ...

# %%
tmp1 = tmp.sample(frac=0.1).reset_index(drop=True)

# %%
tmp1.to_parquet("/home/data/dataset/origin/ebnerd_large/validation/behaviors_sample01.parquet")
